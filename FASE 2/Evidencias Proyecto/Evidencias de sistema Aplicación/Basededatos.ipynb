-- %% [markdown]
-- # [EducAR_BD]

-- %%
/****** Object:  Database [EducAR_BD]    Script Date: 15-10-2024 22:35:49 ******/
CREATE DATABASE [EducAR_BD]  (EDITION = 'GeneralPurpose', SERVICE_OBJECTIVE = 'GP_S_Gen5_2', MAXSIZE = 32 GB) WITH CATALOG_COLLATION = SQL_Latin1_General_CP1_CI_AS, LEDGER = OFF;
GO
ALTER DATABASE [EducAR_BD] SET COMPATIBILITY_LEVEL = 160
GO
ALTER DATABASE [EducAR_BD] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [EducAR_BD] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [EducAR_BD] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [EducAR_BD] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [EducAR_BD] SET ARITHABORT OFF 
GO
ALTER DATABASE [EducAR_BD] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [EducAR_BD] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [EducAR_BD] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [EducAR_BD] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [EducAR_BD] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [EducAR_BD] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [EducAR_BD] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [EducAR_BD] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [EducAR_BD] SET ALLOW_SNAPSHOT_ISOLATION ON 
GO
ALTER DATABASE [EducAR_BD] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [EducAR_BD] SET READ_COMMITTED_SNAPSHOT ON 
GO
ALTER DATABASE [EducAR_BD] SET  MULTI_USER 
GO
ALTER DATABASE [EducAR_BD] SET ENCRYPTION ON
GO
ALTER DATABASE [EducAR_BD] SET QUERY_STORE = ON
GO
ALTER DATABASE [EducAR_BD] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 100, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO
/*** The scripts of database scoped configurations in Azure should be executed inside the target database connection. ***/
GO
-- ALTER DATABASE SCOPED CONFIGURATION SET MAXDOP = 8;
GO

-- %% [markdown]
-- # [dbo].[Accion_Objeto]

-- %%
/****** Object:  Table [dbo].[Accion_Objeto]    Script Date: 15-10-2024 22:35:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Accion_Objeto](
	[Id_Accion] [int] NOT NULL,
	[Id_Objeto] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Accion] ASC,
	[Id_Objeto] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Acciones]

-- %%
/****** Object:  Table [dbo].[Acciones]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Acciones](
	[Id_Accion] [int] IDENTITY(1,1) NOT NULL,
	[Id_Paciente] [int] NOT NULL,
	[Accion] [nvarchar](255) NULL,
	[Respuesta] [nvarchar](255) NULL,
	[Temperatura] [decimal](5, 2) NULL,
	[Presion] [nvarchar](10) NULL,
	[Nivel] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Accion] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categorizacion_triage]

-- %%
/****** Object:  Table [dbo].[Categorizacion_triage]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categorizacion_triage](
	[Id_Categorizacion] [int] IDENTITY(1,1) NOT NULL,
	[Triage] [nvarchar](50) NOT NULL,
	[Descripcion_Triage] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Categorizacion] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Detalle_Evaluacion]

-- %%
/****** Object:  Table [dbo].[Detalle_Evaluacion]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Detalle_Evaluacion](
	[Evaluacion_Id_FK] [int] NOT NULL,
	[Pregunta_Id_FK] [int] NOT NULL,
	[Respuesta] [nvarchar](100) NULL,
	[Secuencia] [int] NOT NULL,
	[EsError] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Evaluacion_Id_FK] ASC,
	[Pregunta_Id_FK] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Escenario_Virtual]

-- %%
/****** Object:  Table [dbo].[Escenario_Virtual]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Escenario_Virtual](
	[Id_Escenario_Virtual] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion_Escenario_virtual] [nvarchar](100) NOT NULL,
	[Duracion_Simulacion] [int] NOT NULL,
	[Nivel_Dificultad] [nvarchar](20) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Escenario_Virtual] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Evaluacion]

-- %%
/****** Object:  Table [dbo].[Evaluacion]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Evaluacion](
	[Id_Evaluacion] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion_Evaluacion] [nvarchar](50) NOT NULL,
	[Usuario_Id_FK] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Evaluacion] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ficha_Medica]

-- %%
/****** Object:  Table [dbo].[Ficha_Medica]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ficha_Medica](
	[Id_Ficha] [int] IDENTITY(1,1) NOT NULL,
	[Fecha_Atencion] [date] NOT NULL,
	[Hora_Atencion] [int] NOT NULL,
	[Tratamiento] [nvarchar](100) NULL,
	[Motivo_Consulta] [nvarchar](100) NULL,
	[Categorizacion_Triage] [nvarchar](30) NULL,
	[Paciente_Id_FK] [int] NOT NULL,
	[Sintomas_SV_Id_FK] [nvarchar](10) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Ficha] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Niveles]

-- %%
/****** Object:  Table [dbo].[Niveles]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Niveles](
	[Id_Nivel] [int] IDENTITY(1,1) NOT NULL,
	[Nivel] [int] NOT NULL,
	[Fecha_Finalizacion] [datetime] NULL,
	[Usuario_Id_FK] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Nivel] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Objetos_AR]

-- %%
/****** Object:  Table [dbo].[Objetos_AR]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Objetos_AR](
	[Id_Objeto] [int] IDENTITY(1,1) NOT NULL,
	[Tipo_Contenido] [nvarchar](60) NULL,
	[url_contenido] [nvarchar](150) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Objeto] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Paciente]

-- %%
/****** Object:  Table [dbo].[Paciente]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Paciente](
	[Id_Paciente] [int] IDENTITY(1,1) NOT NULL,
	[Rut_Paciente] [nvarchar](10) NOT NULL,
	[Nombre_Paciente] [nvarchar](40) NOT NULL,
	[Apellido_Paciente] [nvarchar](40) NOT NULL,
	[Edad] [int] NOT NULL,
	[Genero] [nvarchar](20) NOT NULL,
	[Nivel_Id] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Paciente] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pregunta]

-- %%
/****** Object:  Table [dbo].[Pregunta]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pregunta](
	[id_Pregunta] [int] IDENTITY(1,1) NOT NULL,
	[Pregunta] [nvarchar](100) NOT NULL,
	[Estado] [nvarchar](1) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id_Pregunta] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sintomas_Signos_Vitales]

-- %%
/****** Object:  Table [dbo].[Sintomas_Signos_Vitales]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sintomas_Signos_Vitales](
	[Id_Registro] [nvarchar](10) NOT NULL,
	[Sintomas] [nvarchar](100) NOT NULL,
	[Frecuencia_Cardiaca] [nvarchar](30) NULL,
	[Temperatura] [nvarchar](40) NULL,
	[Nivel_Dolor] [nvarchar](40) NULL,
	[Nivel_Frecuencia] [nvarchar](40) NULL,
	[Saturacion] [nvarchar](30) NULL,
	[Peso] [int] NOT NULL,
	[Categorizacion_triage_Id_FK] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Registro] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tipo_Usuario]

-- %%
/****** Object:  Table [dbo].[Tipo_Usuario]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tipo_Usuario](
	[Id_TipoUsuario] [int] IDENTITY(1,1) NOT NULL,
	[Tipo_Usuario] [nvarchar](20) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_TipoUsuario] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 15-10-2024 22:35:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[Id_Usuario] [int] IDENTITY(1,1) NOT NULL,
	[Nombre_usuario] [nvarchar](100) NOT NULL,
	[Email] [nvarchar](30) NOT NULL,
	[Fecha_registro] [date] NOT NULL,
	[Estado] [nvarchar](10) NOT NULL,
	[Clave] [nvarchar](10) NOT NULL,
	[Tipo_Usuario_Id_FK] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Usuario] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Accion_Objeto_Accion]

-- %%
ALTER TABLE [dbo].[Accion_Objeto]  WITH CHECK ADD  CONSTRAINT [FK_Accion_Objeto_Accion] FOREIGN KEY([Id_Accion])
REFERENCES [dbo].[Acciones] ([Id_Accion])
GO
ALTER TABLE [dbo].[Accion_Objeto] CHECK CONSTRAINT [FK_Accion_Objeto_Accion]
GO

-- %% [markdown]
-- # [FK_Accion_Objeto_Objeto]

-- %%
ALTER TABLE [dbo].[Accion_Objeto]  WITH CHECK ADD  CONSTRAINT [FK_Accion_Objeto_Objeto] FOREIGN KEY([Id_Objeto])
REFERENCES [dbo].[Objetos_AR] ([Id_Objeto])
GO
ALTER TABLE [dbo].[Accion_Objeto] CHECK CONSTRAINT [FK_Accion_Objeto_Objeto]
GO

-- %% [markdown]
-- # [FK_Acciones_Paciente]

-- %%
ALTER TABLE [dbo].[Acciones]  WITH CHECK ADD  CONSTRAINT [FK_Acciones_Paciente] FOREIGN KEY([Id_Paciente])
REFERENCES [dbo].[Paciente] ([Id_Paciente])
GO
ALTER TABLE [dbo].[Acciones] CHECK CONSTRAINT [FK_Acciones_Paciente]
GO

-- %% [markdown]
-- # [FK_Detalle_Evaluacion_Evaluacion]

-- %%
ALTER TABLE [dbo].[Detalle_Evaluacion]  WITH CHECK ADD  CONSTRAINT [FK_Detalle_Evaluacion_Evaluacion] FOREIGN KEY([Evaluacion_Id_FK])
REFERENCES [dbo].[Evaluacion] ([Id_Evaluacion])
GO
ALTER TABLE [dbo].[Detalle_Evaluacion] CHECK CONSTRAINT [FK_Detalle_Evaluacion_Evaluacion]
GO

-- %% [markdown]
-- # [FK_Detalle_Evaluacion_Pregunta]

-- %%
ALTER TABLE [dbo].[Detalle_Evaluacion]  WITH CHECK ADD  CONSTRAINT [FK_Detalle_Evaluacion_Pregunta] FOREIGN KEY([Pregunta_Id_FK])
REFERENCES [dbo].[Pregunta] ([id_Pregunta])
GO
ALTER TABLE [dbo].[Detalle_Evaluacion] CHECK CONSTRAINT [FK_Detalle_Evaluacion_Pregunta]
GO

-- %% [markdown]
-- # [Evaluacion_Usuario_FK]

-- %%
ALTER TABLE [dbo].[Evaluacion]  WITH CHECK ADD  CONSTRAINT [Evaluacion_Usuario_FK] FOREIGN KEY([Usuario_Id_FK])
REFERENCES [dbo].[Usuario] ([Id_Usuario])
GO
ALTER TABLE [dbo].[Evaluacion] CHECK CONSTRAINT [Evaluacion_Usuario_FK]
GO

-- %% [markdown]
-- # [Ficha_Medica_Paciente_FK]

-- %%
ALTER TABLE [dbo].[Ficha_Medica]  WITH CHECK ADD  CONSTRAINT [Ficha_Medica_Paciente_FK] FOREIGN KEY([Paciente_Id_FK])
REFERENCES [dbo].[Paciente] ([Id_Paciente])
GO
ALTER TABLE [dbo].[Ficha_Medica] CHECK CONSTRAINT [Ficha_Medica_Paciente_FK]
GO

-- %% [markdown]
-- # [Ficha_Medica_Sintomas_Signos_Vitales_FK]

-- %%
ALTER TABLE [dbo].[Ficha_Medica]  WITH CHECK ADD  CONSTRAINT [Ficha_Medica_Sintomas_Signos_Vitales_FK] FOREIGN KEY([Sintomas_SV_Id_FK])
REFERENCES [dbo].[Sintomas_Signos_Vitales] ([Id_Registro])
GO
ALTER TABLE [dbo].[Ficha_Medica] CHECK CONSTRAINT [Ficha_Medica_Sintomas_Signos_Vitales_FK]
GO

-- %% [markdown]
-- # [FK_Paciente_Nivel]

-- %%
ALTER TABLE [dbo].[Paciente]  WITH CHECK ADD  CONSTRAINT [FK_Paciente_Nivel] FOREIGN KEY([Nivel_Id])
REFERENCES [dbo].[Niveles] ([Id_Nivel])
GO
ALTER TABLE [dbo].[Paciente] CHECK CONSTRAINT [FK_Paciente_Nivel]
GO

-- %% [markdown]
-- # [EducAR_BD]

-- %%
ALTER DATABASE [EducAR_BD] SET  READ_WRITE 
GO
